# %%
import numpy as np

# %%
a = np.eye(2) # [[1., 0.],[0., 1.]]
type(a[0,0])
# Out:
# numpy.float64

# %%
b = np.random.random((3,5,3))

# %%
b
# Out:
# array([[[0.81214   , 0.74255092, 0.45555196],
#         [0.07891035, 0.17320169, 0.41537644],
#         [0.17833275, 0.06456335, 0.5066794 ],
#         [0.27357037, 0.79159125, 0.73858332],
#         [0.90476602, 0.15620095, 0.75077278]],
#
#        [[0.20964765, 0.60782347, 0.31816587],
#         [0.56296251, 0.67662066, 0.6663994 ],
#         [0.4803136 , 0.35830996, 0.03823825],
#         [0.00347183, 0.64384327, 0.02414131],
#         [0.69804405, 0.7149595 , 0.0721153 ]],
#
#        [[0.2265288 , 0.80455381, 0.87215306],
#         [0.3417546 , 0.45769346, 0.88187806],
#         [0.97085829, 0.1639631 , 0.13794374],
#         [0.12691611, 0.32327508, 0.94078091],
#         [0.67808585, 0.54630687, 0.75915453]]])

# %%
b[1, 3, 2]
# Out:
# 0.024141308106395476

# %%
b[1]
# Out:
# array([[0.20964765, 0.60782347, 0.31816587],
#        [0.56296251, 0.67662066, 0.6663994 ],
#        [0.4803136 , 0.35830996, 0.03823825],
#        [0.00347183, 0.64384327, 0.02414131],
#        [0.69804405, 0.7149595 , 0.0721153 ]])

# %%
b[1, 3].shape
# Out:
# (3,)

# %%
a = np.random.random((3,4))

# %%
a
# Out:
# array([[0.44658507, 0.05122823, 0.55229485, 0.18993817],
#        [0.55395612, 0.57354935, 0.94414461, 0.23263646],
#        [0.47780126, 0.95407924, 0.62154097, 0.37282812]])

# %%
b = a[1:, 2]
b
# Out:
# array([0.94414461, 0.62154097])

# %%
b[0] = 2

# %%
b
# Out:
# array([2.        , 0.62154097])

# %%
a
# Out:
# array([[0.44658507, 0.05122823, 0.55229485, 0.18993817],
#        [0.55395612, 0.57354935, 2.        , 0.23263646],
#        [0.47780126, 0.95407924, 0.62154097, 0.37282812]])

# %%
a[[1, 2, 2], [0, 1 ,1 ]]
# Out:
# array([0.55395612, 0.95407924, 0.95407924])

# %%
c = a[[1,2,2], [0,1, 1]]

# %%
c
# Out:
# array([0.55395612, 0.95407924, 0.95407924])

# %%
c[2] = 8

# %%
a
# Out:
# array([[0.44658507, 0.05122823, 0.55229485, 0.18993817],
#        [0.55395612, 0.57354935, 2.        , 0.23263646],
#        [0.47780126, 0.95407924, 0.62154097, 0.37282812]])

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
iris = load_iris()

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# df.iloc[[0],:4]
# df.loc[0]
# df['index1'] = np.arange(150)+1

# %%
# df= df.set_index('index1')
# # df.set_index('sepal length (cm)')
# # df = df.reset_index()
# df.loc[2]

# %%
# # df.rename(columns = {'sepal length (cm)' : 'sl', 'sepal width (cm)' : 'sw',
# #                     'petal length (cm)' : 'pl', 'petal width (cm)' : 'pw' }, inplace = True)

# df['sl'] = df['sl'].apply(lambda x : x*2)
# # df['sl'].value_counts()
# df

# %%
df2 = pd.DataFrame(iris.data, columns=iris.feature_names)
df2.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df.rename(columns = {'sepal length (cm)' : 'sl', 'sepal width (cm)' : 'sw',
                    'petal length (cm)' : 'pl', 'petal width (cm)' : 'pw' }, inplace = True)

df2.rename(columns = {'sepal length (cm)' : 'sl', 'sepal width (cm)' : 'sw2',
                    'petal length (cm)' : 'pl2', 'petal width (cm)' : 'pw2' }, inplace = True)

# %%
df.head()
# Out:
#     sl   sw   pl   pw
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
df2.head()
df.loc[df['sl']>7, ['sl','pw']]
# Out:
#       sl   pw
# 102  7.1  2.1
# 105  7.6  2.1
# 107  7.3  1.8
# 109  7.2  2.5
# 117  7.7  2.2
# 118  7.7  2.3
# 122  7.7  2.0
# 125  7.2  1.8
# 129  7.2  1.6
# 130  7.4  1.9
# 131  7.9  2.0
# 135  7.7  2.3

# %%
test= pd.concat([df,df2], axis= 1)
test
# Out:
#       sl   sw   pl   pw   sl  sw2  pl2  pw2
# 0    5.1  3.5  1.4  0.2  5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2  4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2  4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2  4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2  5.0  3.6  1.4  0.2
# 5    5.4  3.9  1.7  0.4  5.4  3.9  1.7  0.4
# 6    4.6  3.4  1.4  0.3  4.6  3.4  1.4  0.3
# 7    5.0  3.4  1.5  0.2  5.0  3.4  1.5  0.2
# 8    4.4  2.9  1.4  0.2  4.4  2.9  1.4  0.2
# 9    4.9  3.1  1.5  0.1  4.9  3.1  1.5  0.1
# 10   5.4  3.7  1.5  0.2  5.4  3.7  1.5  0.2
# 11   4.8  3.4  1.6  0.2  4.8  3.4  1.6  0.2
# 12   4.8  3.0  1.4  0.1  4.8  3.0  1.4  0.1
# 13   4.3  3.0  1.1  0.1  4.3  3.0  1.1  0.1
# 14   5.8  4.0  1.2  0.2  5.8  4.0  1.2  0.2
# 15   5.7  4.4  1.5  0.4  5.7  4.4  1.5  0.4
# 16   5.4  3.9  1.3  0.4  5.4  3.9  1.3  0.4
# 17   5.1  3.5  1.4  0.3  5.1  3.5  1.4  0.3
# 18   5.7  3.8  1.7  0.3  5.7  3.8  1.7  0.3
# 19   5.1  3.8  1.5  0.3  5.1  3.8  1.5  0.3
# ...
